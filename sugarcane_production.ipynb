# %% [markdown]
# <a href="https://colab.research.google.com/github/0Priya99/sugarcane_production-using-pandas/blob/main/sugarcane_production.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/ Sugarcane Production .csv")
df
# Out:
#      Unnamed: 0    Country      Continent Production (Tons)  \
# 0             0     Brazil  South America       768.678.382
# 1             1      India           Asia       348.448.000
# 2             2      China           Asia       123.059.739
# 3             3   Thailand           Asia        87.468.496
# 4             4   Pakistan           Asia        65.450.704
# ..          ...        ...            ...               ...
# 98           98    Lebanon           Asia                97
# 99           99   Djibouti         Africa                53
# 100         100  Singapore           Asia                50
# 101         101      Samoa        Oceania                12
# 102         102      Syria           Asia                 1
#
#     Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                    3.668,531        10.226.205             75.167,5
# 1                       260721         4.950.000             70.393,5
# ...

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America       768.678.382
# 1           1     India           Asia       348.448.000
# 2           2     China           Asia       123.059.739
# 3           3  Thailand           Asia        87.468.496
# 4           4  Pakistan           Asia        65.450.704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                  3.668,531        10.226.205             75.167,5
# 1                     260721         4.950.000             70.393,5
# 2                      88287         1.675.215             73.459,1
# 3                  1.264,303         1.336.575             65.442,2
# 4                     324219         1.130.820               57.879

# %%
df.shape
# Out:
# (103, 7)

# %%
df.dtypes
# Out:
# Unnamed: 0                     int64
# Country                       object
# Continent                     object
# Production (Tons)             object
# Production per Person (Kg)    object
# Acreage (Hectare)             object
# Yield (Kg / Hectare)          object
# dtype: object

# %%
df.nunique()
# Out:
# Unnamed: 0                    103
# Country                       103
# Continent                       6
# Production (Tons)             103
# Production per Person (Kg)    102
# Acreage (Hectare)             102
# Yield (Kg / Hectare)          102
# dtype: int64

# %%
df.tail()
# Out:
#      Unnamed: 0    Country Continent Production (Tons)  \
# 98           98    Lebanon      Asia                97
# 99           99   Djibouti    Africa                53
# 100         100  Singapore      Asia                50
# 101         101      Samoa   Oceania                12
# 102         102      Syria      Asia                 1
#
#     Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 98                          16                 3             28.386,4
# 99                          51               NaN                  NaN
# 100                          9                 2                   25
# 101                          6                 1             11.949,8
# 102                          0                 0             83.034,2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  103 non-null    int64
#  1   Country                     103 non-null    object
#  2   Continent                   103 non-null    object
#  3   Production (Tons)           103 non-null    object
#  4   Production per Person (Kg)  103 non-null    object
#  5   Acreage (Hectare)           102 non-null    object
#  6   Yield (Kg / Hectare)        102 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 5.8+ KB

# %%
df["Production (Tons)"]=df["Production (Tons)"].str.replace(".","")
df["Acreage (Hectare)"]=df["Acreage (Hectare)"].str.replace(".","")

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America         768678382
# 1           1     India           Asia         348448000
# 2           2     China           Asia         123059739
# 3           3  Thailand           Asia          87468496
# 4           4  Pakistan           Asia          65450704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                  3.668,531          10226205             75.167,5
# 1                     260721           4950000             70.393,5
# 2                      88287           1675215             73.459,1
# 3                  1.264,303           1336575             65.442,2
# 4                     324219           1130820               57.879

# %%
df["Production per Person (Kg)"]=df["Production per Person (Kg)"].str.replace(".","").str.replace(",",".")
df["Yield (Kg / Hectare)"]=df["Yield (Kg / Hectare)"].str.replace(".","").str.replace(",",".")

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America         768678382
# 1           1     India           Asia         348448000
# 2           2     China           Asia         123059739
# 3           3  Thailand           Asia          87468496
# 4           4  Pakistan           Asia          65450704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                   3668.531          10226205              75167.5
# 1                     260721           4950000              70393.5
# 2                      88287           1675215              73459.1
# 3                   1264.303           1336575              65442.2
# 4                     324219           1130820                57879

# %%
df.isna().sum()
# Out:
# Unnamed: 0                    0
# Country                       0
# Continent                     0
# Production (Tons)             0
# Production per Person (Kg)    0
# Acreage (Hectare)             1
# Yield (Kg / Hectare)          1
# dtype: int64

# %%
df[df["Acreage (Hectare)"].isnull()]
# Out:
#     Unnamed: 0   Country Continent Production (Tons)  \
# 99          99  Djibouti    Africa                53
#
#    Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 99                         51               NaN                  NaN

# %%
df.dropna().reset_index()
# Out:
#      index  Unnamed: 0    Country      Continent Production (Tons)  \
# 0        0           0     Brazil  South America         768678382
# 1        1           1      India           Asia         348448000
# 2        2           2      China           Asia         123059739
# 3        3           3   Thailand           Asia          87468496
# 4        4           4   Pakistan           Asia          65450704
# ..     ...         ...        ...            ...               ...
# 97      97          97      Spain         Europe               394
# 98      98          98    Lebanon           Asia                97
# 99     100         100  Singapore           Asia                50
# 100    101         101      Samoa        Oceania                12
# 101    102         102      Syria           Asia                 1
#
#     Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                     3668.531          10226205              75167.5
# ...

# %%
df.drop(["Unnamed: 0"], axis = 1, inplace = True)

# %%
df.head()
# Out:
#     Country      Continent Production (Tons) Production per Person (Kg)  \
# 0    Brazil  South America         768678382                   3668.531
# 1     India           Asia         348448000                     260721
# 2     China           Asia         123059739                      88287
# 3  Thailand           Asia          87468496                   1264.303
# 4  Pakistan           Asia          65450704                     324219
#
#   Acreage (Hectare) Yield (Kg / Hectare)
# 0          10226205              75167.5
# 1           4950000              70393.5
# 2           1675215              73459.1
# 3           1336575              65442.2
# 4           1130820                57879

# %% [markdown]
# **UNIVARIATE ANALYSIS**

# %%
df.head()
# Out:
#     Country      Continent Production (Tons) Production per Person (Kg)  \
# 0    Brazil  South America         768678382                   3668.531
# 1     India           Asia         348448000                     260721
# 2     China           Asia         123059739                      88287
# 3  Thailand           Asia          87468496                   1264.303
# 4  Pakistan           Asia          65450704                     324219
#
#   Acreage (Hectare) Yield (Kg / Hectare)
# 0          10226205              75167.5
# 1           4950000              70393.5
# 2           1675215              73459.1
# 3           1336575              65442.2
# 4           1130820                57879

# %%
df["Continent"].value_counts()
# Out:
# Continent
# Africa           39
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: count, dtype: int64

# %% [markdown]
# how many countries produce sugarcane from each **contient**

# %%
df["Continent"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Continent'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.distplot(df["Production (Tons)"])
plt.subplot(2,2,2)
sns.distplot(df["Production per Person (Kg)"])
plt.subplot(2,2,3)
sns.distplot(df["Acreage (Hectare)"])
plt.subplot(2,2,4)
sns.distplot(df["Yield (Kg / Hectare)"])
# Out:
# /tmp/ipython-input-2425897376.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Production (Tons)"])
# /tmp/ipython-input-2425897376.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Production per Person (Kg)"])
# ...

# %%
df.describe()
# Out:
#        Country Continent Production (Tons) Production per Person (Kg)  \
# count      103       103               103                        103
# unique     103         6               103                        102
# top     Brazil    Africa         768678382                        297
# freq         1        39                 1                          2
#
#        Acreage (Hectare) Yield (Kg / Hectare)
# count                102                  102
# unique               101                  102
# top                  584              75167.5
# freq                   2                    1

# %% [markdown]
# BIVARIENT ANALYSIS

# %%
df.head()
# Out:
#     Country      Continent Production (Tons) Production per Person (Kg)  \
# 0    Brazil  South America         768678382                   3668.531
# 1     India           Asia         348448000                     260721
# 2     China           Asia         123059739                      88287
# 3  Thailand           Asia          87468496                   1264.303
# 4  Pakistan           Asia          65450704                     324219
#
#   Acreage (Hectare) Yield (Kg / Hectare)
# 0          10226205              75167.5
# 1           4950000              70393.5
# 2           1675215              73459.1
# 3           1336575              65442.2
# 4           1130820                57879

# %%
df_new=df[["Country","Production (Tons)"]].set_index("Country")

# %%
df_new
# Out:
#           Production (Tons)
# Country
# Brazil            768678382
# India             348448000
# China             123059739
# Thailand           87468496
# Pakistan           65450704
# ...                     ...
# Lebanon                  97
# Djibouti                 53
# Singapore                50
# Samoa                    12
# Syria                     1
#
# [103 rows x 1 columns]

# %%
df_new=df[["Country","Production (Tons)"]].set_index("Country")

# %%
df_new["Production (Tons)"] = pd.to_numeric(df_new["Production (Tons)"], errors="coerce")

# %%
df_new["production (Tons) percentage"] = df_new["Production (Tons)"]*100 / df_new["Production (Tons)"].sum()

# %%
df_new
# Out:
#            Production (Tons)  production (Tons) percentage
# Country
# Brazil             768678382                  4.072728e+01
# India              348448000                  1.846200e+01
# China              123059739                  6.520138e+00
# Thailand            87468496                  4.634389e+00
# Pakistan            65450704                  3.467809e+00
# ...                      ...                           ...
# Lebanon                   97                  5.139401e-06
# Djibouti                  53                  2.808126e-06
# Singapore                 50                  2.649176e-06
# Samoa                     12                  6.358022e-07
# Syria                      1                  5.298352e-08
#
# [103 rows x 2 columns]

# %%
df_new["production (Tons) percentage"].plot(kind="pie",autopct ="%.2f")
# Out:
# <Axes: ylabel='production (Tons) percentage'>

# %%
df_new["Production (Tons)"].head(10).plot(kind="bar")
# Out:
# <Axes: xlabel='Country'>

# %% [markdown]
# CORRELATION

# %%
df_numeric = df[["Production (Tons)", "Production per Person (Kg)", "Acreage (Hectare)", "Yield (Kg / Hectare)"]].copy()
df_numeric["Production (Tons)"] = pd.to_numeric(df_numeric["Production (Tons)"], errors="coerce")
df_numeric["Production per Person (Kg)"] = pd.to_numeric(df_numeric["Production per Person (Kg)"], errors="coerce")
df_numeric["Acreage (Hectare)"] = pd.to_numeric(df_numeric["Acreage (Hectare)"], errors="coerce")
df_numeric["Yield (Kg / Hectare)"] = pd.to_numeric(df_numeric["Yield (Kg / Hectare)"], errors="coerce")
correlation_matrix = df_numeric.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Sugarcane Production Data')
plt.show()

# %%
sns.scatterplot(data=df.head(10),x="Acreage (Hectare)",y="Production (Tons)")
# Out:
# <Axes: xlabel='Acreage (Hectare)', ylabel='Production (Tons)'>

# %%
sns.scatterplot(data=df.head(20),x="Yield (Kg / Hectare)",y="Production (Tons)")
# Out:
# <Axes: xlabel='Yield (Kg / Hectare)', ylabel='Production (Tons)'>

# %%
df_continent=df.groupby("Continent").sum()

# %%
df_continent
# Out:
#                                                          Country  \
# Continent
# Africa         EgyptSouth AfricaKenyaSwazilandSudanZambiaMaur...
# Asia           IndiaChinaThailandPakistanIndonesiaPhilippines...
# Europe                                             PortugalSpain
# North America  MexicoGuatemalaUnited States of AmericaCubaEl ...
# Oceania                       AustraliaFijiPapua New GuineaSamoa
# South America  BrazilColombiaArgentinaPeruEcuadorBoliviaParag...
#
#                                                Production (Tons)  \
# Continent
# Africa         1576041815074610709461955832955525059428583937...
# Asia           3484480001230597398746849665450704271588302237...
# Europe                                                   5429394
# North America  5644682133533403299262101889097272021416815147...
# Oceania                                  34403004155669221786612
# South America  7686783823695121321990823983252686616096910805...
#
# ...

# %%
df_continent["Production (Tons)"] = pd.to_numeric(df_continent["Production (Tons)"], errors='coerce')

# %%
df_continent["Production (Tons)"].sort_values(ascending=False).plot(kind="bar")
# Out:
# <Axes: xlabel='Continent'>

# %%
df_continent["Acreage (Hectare)"] = pd.to_numeric(df_continent["Acreage (Hectare)"], errors='coerce')

# %%
df_continent["Acreage (Hectare)"].sort_values(ascending=False).plot(kind="bar")
# Out:
# <Axes: xlabel='Continent'>

# %%
df_continent["numbers of countries"]=df.groupby("Continent").count()["Country"]

# %%
df_continent
# Out:
# /usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py:1016: RuntimeWarning: overflow encountered in square
#   sqr = _ensure_numeric((avg - values) ** 2)
# /usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py:1016: RuntimeWarning: overflow encountered in square
#   sqr = _ensure_numeric((avg - values) ** 2)
#                                                          Country  \
# Continent
# Africa         EgyptSouth AfricaKenyaSwazilandSudanZambiaMaur...
# Asia           IndiaChinaThailandPakistanIndonesiaPhilippines...
# Europe                                             PortugalSpain
# North America  MexicoGuatemalaUnited States of AmericaCubaEl ...
# Oceania                       AustraliaFijiPapua New GuineaSamoa
# South America  BrazilColombiaArgentinaPeruEcuadorBoliviaParag...
#
#                Production (Tons)  \
# Continent
# Africa             1.576042e+242
# Asia               3.484480e+144
# Europe              5.429394e+06
# ...

# %%
continent_names=df_continent.index.to_list()
sns.lineplot(data=df_continent,x="numbers of countries",y="Production (Tons)")
plt.xticks(df_continent["numbers of countries"],continent_names,rotation=90)
plt.show()
